# %% [markdown]
# ---
# ---
#
# # Exercises: Automated Data Collection
#
# (Based on content from the recitation of the "Applied Data Science using Python" course from New York University Abu Dhabi.)
#
# ---
# ---

# %% [markdown]
# # Part I: Bayt
#
# Let's scrape one of the leading job sites in the Middle East: https://www.bayt.com/en/uae/jobs/
#
# For each randomly chosen page, go to job posting's page and scrape the `Job Details` table.
#
#
#
# *Make sure you time your requests.*

# %% [markdown]
# ## A: The Job Details Table

# %% [markdown]
# Write a function called `job_details()` that will take as an input the partial url for the job, scrape the table information from the table and return as a Pandas Series. In addition, the Series should contain the job ID.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

sample_url = '/en/uae/jobs/personal-assistant-4870043/'

def job_details(partial_url):
    header = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
    }
    main_url =  "https://www.bayt.com"
    
    request = requests.get(main_url + partial_url)
    soup = BeautifulSoup(request.text, 'html.parser')
    table = soup.find('dl', class_ = 'dlist')
    descriptors = ['jobID']
    
    descriptors = descriptors + [item.text for item in table.find_all('dt')]
    values = [sample_url.split('/')[-2].split('-')[-1]]
    values = values + [item.text for item in table.find_all('dd')]
    
    concatenated = pd.Series(values, index = descriptors)
    return concatenated


job_details(sample_url)
# Out:
# jobID                                                   4870043
# Job Location                        Dubai United Arab Emirates
# Company Industry        Recruitment & Employee Placement Agency
# Company Type                          Employer (Private Sector)
# Job Role                                         Administration
# Employment Type                              Full Time Employee
# Monthly Salary Range                                Unspecified
# Number of Vacancies                                           1
# dtype: object

# %% [markdown]
# ## B: Getting the Partial URLs

# %% [markdown]
# Now that we have a function that scrapes the required information, let's write another function called `partial_urls()` that will take as an input the page number and return all the partial urls for all jobs as a list.

# %%
def partial_urls(page):
    header = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
    }
    main_url = "https://www.bayt.com/en/uae/jobs/?page="
    request = requests.get(main_url + str(page))
    soup = BeautifulSoup(request.text, 'html.parser')
    partial_urls = [item['href'] for item in soup.find_all('a', attrs = {'data-js-aid':"jobID"})]
    return partial_urls

partial_urls(11)
# Out:
# ['/en/uae/jobs/accountant-4903494/',
#  '/en/uae/jobs/office-boy-4903524/',
#  '/en/uae/jobs/civil-engineer-4903525/',
#  '/en/uae/jobs/site-engineer-civil-4903560/',
#  '/en/uae/jobs/fit-out-project-manager-russian-4903564/',
#  '/en/uae/jobs/front-desk-receptionist-4904715/',
#  '/en/uae/jobs/telesales-executive-4903568/',
#  '/en/uae/jobs/site-civil-engineer-4903573/',
#  '/en/uae/jobs/real-estate-leasing-consultant-4904713/',
#  '/en/uae/jobs/labour-4903640/',
#  '/en/uae/jobs/sales-merchandiser-4903813/',
#  '/en/uae/jobs/cashier-4903844/',
#  '/en/uae/jobs/security-guard-4903878/',
#  '/en/uae/jobs/assistant-accountant-4903880/',
#  '/en/uae/jobs/administrative-assistant-with-russia-language-4904633/',
#  '/en/uae/jobs/administrative-assistant-4904636/',
#  '/en/uae/jobs/driver-4904704/',
#  '/en/uae/jobs/legal-and-compliance-officer-4904707/',
#  '/en/uae/jobs/dental-sales-executive-4903368/',
#  '/en/uae/jobs/marketing-specialist-4903490/']

# %% [markdown]
# ## C: Putting it all together

# %% [markdown]
# Finally, let's write a function that will take as an input a list of page numbers, then get all the partial urls, scrape the job information and return a Pandas DataFrame with all the information.

# %%
def bayt(pages):
    data = pd.DataFrame()
# Write your code below this line
######### SOLUTION #########

    for page in pages:
        partial_urls_list = partial_urls(page)
        for partial_url in partial_urls_list:
            data = data.append(job_details(partial_url), ignore_index = True)
            



######### SOLUTION END #########

    return data

bayt([11])
# Out:
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
#       jobID                      Job Location  \
# 0   4870043       Dubai United Arab Emirates
# 1   4870043       Dubai United Arab Emirates
# 2   4870043       Dubai United Arab Emirates
# 3   4870043   Abu Dhabi United Arab Emirates
# 4   4870043       Dubai United Arab Emirates
# 5   4870043       Dubai United Arab Emirates
# 6   4870043       Dubai United Arab Emirates
# 7   4870043    Fujairah United Arab Emirates
# 8   4870043       Dubai United Arab Emirates
# 9   4870043    Fujairah United Arab Emirates
# 10  4870043    Fujairah United Arab Emirates
# 11  4870043    Fujairah United Arab Emirates
# 12  4870043       Dubai United Arab Emirates
# 13  4870043       Dubai United Arab Emirates
# 14  4870043       Dubai United Arab Emirates
# 15  4870043       Dubai United Arab Emirates
# 16  4870043       Dubai United Arab Emirates
# 17  4870043   Abu Dhabi United Arab Emirates
# 18  4870043   Abu Dhabi United Arab Emirates
# 19  4870043       Dubai United Arab Emirates
#
#                                      Company Industry  \
# 0   Accounting; Administration Support Services; C...
# 1   Administration Support Services; Corporate Man...
# 2                     General Engineering Consultancy
# 3                       Business Consultancy Services
# 4            Interior design; Construction & Building
# 5                                         Real Estate
# 6   Advertising; Telemarketing; Call Centers & Cus...
# 7                             Construction & Building
# 8                     Administration Support Services
# 9                             Construction & Building
# 10                                 Retail & Wholesale
# 11                                 Retail & Wholesale
# 12                    Administration Support Services
# 13                    Administration Support Services
# 14                    Administration Support Services
# 15                                 Financial Services
# 16                              Public Relations (PR)
# 17                                 Financial Services
# 18                             Dental Center & Clinic
# 19  Marketing; Advertising; Administration Support...
#
#                  Company Type                             Job Role  \
# 0                 Unspecified              Accounting and Auditing
# 1                 Unspecified                       Administration
# 2                 Unspecified                    Civil Engineering
# 3                 Unspecified                    Civil Engineering
# 4                 Unspecified           Design, Creative, and Arts
# 5   Employer (Private Sector)                       Administration
# 6                 Unspecified                                Sales
# 7                 Unspecified                    Civil Engineering
# 8                 Unspecified                                Sales
# 9                 Unspecified  Maintenance, Repair, and Technician
# 10                Unspecified                                Sales
# 11                Unspecified              Accounting and Auditing
# 12                Unspecified                             Security
# 13                Unspecified              Accounting and Auditing
# 14  Employer (Private Sector)                       Administration
# 15  Employer (Private Sector)                       Administration
# 16                Unspecified         Logistics and Transportation
# 17    Non-Profit Organization               Finance and Investment
# 18                Unspecified                                Sales
# 19                Unspecified                     Marketing and PR
#
#        Employment Type Monthly Salary Range Number of Vacancies
# 0   Full Time Employee        $500 - $1,000                   4
# 1   Full Time Employee        $500 - $1,000                   5
# 2   Full Time Employee          Unspecified                   1
# 3   Full Time Employee          Unspecified                   1
# 4   Full Time Employee          Unspecified                   1
# 5   Full Time Employee          Unspecified                   1
# 6   Full Time Employee          Unspecified                   6
# 7   Full Time Employee          Unspecified                   1
# 8   Full Time Employee      $1,000 - $1,500                   1
# 9   Full Time Employee          Unspecified                   5
# 10  Full Time Employee          Unspecified                  10
# 11  Full Time Employee            $0 - $500                   3
# 12  Full Time Employee          Unspecified                   1
# 13  Full Time Employee          Unspecified                   1
# 14  Full Time Employee      $2,000 - $3,000                   1
# 15  Full Time Employee      $2,000 - $3,000                   1
# 16  Full Time Employee          Unspecified                   1
# 17  Full Time Employee          Unspecified                   1
# 18  Full Time Employee          Unspecified                   1
# 19  Full Time Employee        $500 - $1,000                   5

# %% [markdown]
# ## D: Looking at the data

# %% [markdown]
# Let's scrape 5 pages selected at random, and using the resulting dataframe, answer the following questions:
#
#
# 1.   What proportion of job postings have not specified a monthly salary range?
# 2.   What proportion of job postings are from private sector and what proportion of job postings are from public sector?

# %%
import numpy as np
import time
import random
from numpy.random import default_rng
random.seed(27)

rng = default_rng()
pages = rng.choice(20, size=5, replace=False)

# %%
# Write your code below this line
######### SOLUTION #########

df = bayt(pages)

print(df['Monthly Salary Range'].value_counts(normalize = True))
print(df['Company Type'].value_counts())
######### SOLUTION END #########
# Out:
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)
# Unspecified        0.61
# $500 - $1,000      0.18
# $1,000 - $1,500    0.10
# $0 - $500          0.04
# $2,000 - $3,000    0.02
# $6,000 - $7,000    0.02
# $3,000 - $4,000    0.02
# $4,000 - $5,000    0.01
# Name: Monthly Salary Range, dtype: float64
# Unspecified                  54
# Employer (Private Sector)    43
# Recruitment Agency            3
# Name: Company Type, dtype: int64
# /var/folders/q2/jh49nbrj73x3lvwvlz9642xm0000gp/T/ipykernel_46383/4016825758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(job_details(partial_url), ignore_index = True)

# %% [markdown]
# Write your answers below:
#
# 1.   What proportion of job postings have not specified a monthly salary range? [Your answer]
# 2.   What proportion of job postings are from private sector and what proportion of job postings are from public sector? [Your answer]

# %% [markdown]
# # Part II: Hindi Geet Mala

# %% [markdown]
# For this part, following the same logic as in Part I, scrape https://www.hindigeetmala.net/ website, in order to answer the following question.
#
# *Has the average number of songs in a movie increased in 2018 compared to 1930s?*

# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

years = ['2018', '1930s']

header = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
}

# %%
def get_movie_urls(year, page):
    # Write your code below this line
    ######### SOLUTION #########
    main_url = 'https://www.hindilyrics4u.com/movie/' + str(year) + '.php?page=' + str(page)
    
    request = requests.get(main_url)
    soup = BeautifulSoup(request.text, 'html.parser')
    movies = soup.find_all('td', class_ = 'w25p')
    movie_links = [item.find('a')['href'] for item in movies]
    print(movie_links)
    return movie_links



    ######### SOLUTION END #########

    # return [] # return a list of movie urls

get_movie_urls("2018", 1)
# Out:
# ['/movie/batti_gul_meter_chalu.htm', '/movie/dhadak.htm', '/movie/gold.htm', '/movie/loveratri.htm', '/movie/nawabzaade.htm', '/movie/satyameva_jayate.htm', '/movie/veere_di_wedding.htm', '/movie/stree_2018.htm', '/movie/102_not_out.htm', '/movie/3_storeys.htm', '/movie/aiyaary.htm', '/movie/angrezi_mein_kehte_hain.htm', '/movie/baa_baaa_black_sheep.htm', '/movie/baaghi_2.htm', '/movie/beyond_the_clouds.htm', '/movie/bhavesh_joshi_superhero.htm', '/movie/billu_ustaad.htm', '/movie/blackmail_2018.htm', '/movie/daas_dev.htm', '/movie/daddys_daughter.htm']
# ['/movie/batti_gul_meter_chalu.htm',
#  '/movie/dhadak.htm',
#  '/movie/gold.htm',
#  '/movie/loveratri.htm',
#  '/movie/nawabzaade.htm',
#  '/movie/satyameva_jayate.htm',
#  '/movie/veere_di_wedding.htm',
#  '/movie/stree_2018.htm',
#  '/movie/102_not_out.htm',
#  '/movie/3_storeys.htm',
#  '/movie/aiyaary.htm',
#  '/movie/angrezi_mein_kehte_hain.htm',
#  '/movie/baa_baaa_black_sheep.htm',
#  '/movie/baaghi_2.htm',
#  '/movie/beyond_the_clouds.htm',
#  '/movie/bhavesh_joshi_superhero.htm',
#  '/movie/billu_ustaad.htm',
#  '/movie/blackmail_2018.htm',
#  '/movie/daas_dev.htm',
#  '/movie/daddys_daughter.htm']

# %%
def get_num_songs(movie_url):
    # Write your code below this line
    ######### SOLUTION #########
    main = 'https://www.hindilyrics4u.com/' + movie_url
    request = requests.get(main)
    soup = BeautifulSoup(request.text, 'html.parser')
    return len(soup.find_all('tr', attrs = {'itemprop' : 'track'}))


    ######### SOLUTION END #########

get_num_songs("movie/avtaar.htm")
# Out:
# 6

# %%
def average_num_songs(year_list):
    song_counter = {}

    for year in year_list:
        print("scraping year", year)
        page = 1
        movie_name = ""
        movies = get_movie_urls(year, page)
        while movies[0] != movie_name:
            for movie in movies:
                if year in song_counter.keys():
                    song_counter[year]+=[get_num_songs(movie)]
                else:
                    song_counter[year]=[get_num_songs(movie)]
            movie_name = movies[0]
            page += 1
            movies = get_movie_urls(year, page)

    for year in year_list:
        avg = sum(song_counter[year])/len(song_counter[year])
        print("average number of songs for year {} is {}".format(year,avg))

average_num_songs(["1930s", "2018"])
# Out:
# scraping year 1930s
# ['/movie/alam_ara.htm', '/movie/devdas.htm', '/movie/aadmi_1939.htm', '/movie/aap_ki_marzi.htm', '/movie/achhut_kanya.htm', '/movie/adhikar.htm', '/movie/amar_jyoti_1936.htm', '/movie/amrit_manthan.htm', '/movie/aurat_ka_pyar.htm', '/movie/bhabhi.htm', '/movie/bhasmaasur_mohini.htm', '/movie/bilwamangal_1932.htm', '/movie/chandi_das.htm', '/movie/deccan_queen_1936.htm', '/movie/dhoop_chhaon.htm', '/movie/draupadi_1931.htm', '/movie/duniya_na_mane.htm', '/movie/dushman.htm', '/movie/ek_hi_rasta.htm', '/movie/gangavataran.htm']
# ['/movie/gopal_krishna.htm', '/movie/gramophone_singer.htm', '/movie/harischandra.htm', '/movie/heer_raanjha_1931.htm', '/movie/hunterwali_1935.htm', '/movie/indra_sabha.htm', '/movie/inquilab.htm', '/movie/izzat.htm', '/movie/jagirdar.htm', '/movie/janmabhoomi.htm', '/movie/jeevan_prabhat.htm', '/movie/kangan.htm', '/movie/kapala_kundala.htm', '/movie/lal_e_yaman.htm', '/movie/maya_machhindar.htm', '/movie/nirmala.htm', '/movie/noorjehan.htm', '/movie/prem_kahani_1937.htm', '/movie/pujarin.htm', '/movie/pukar.htm']
# ['/movie/puran_bhagat.htm', '/movie/raja_harishchandra.htm', '/movie/rajrani_meeraa.htm', '/movie/sairandhri.htm', '/movie/sati_savitri.htm', '/movie/savitri.htm', '/movie/shirin_farhad.htm', '/movie/shyam_sunder.htm', '/movie/street_singer.htm', '/movie/sultana.htm', '/movie/thokar.htm', '/movie/toofani_tarzan.htm', '/movie/vachan_1938.htm', '/movie/vidyapati.htm', '/movie/yahudi_ki_ladki.htm', '/movie/madam_fashion.htm', '/movie/manmohan.htm', '/movie/manzil.htm', '/movie/mother_india_1938.htm', '/movie/punjab_mail.htm']
# ['/movie/sant_tulsidas.htm', '/movie/sapera.htm', '/movie/dharti_mata.htm', '/movie/gul_e_bakawali_punjabi_film.htm', '/movie/kaarwaan_e_hayaat.htm', '/movie/millionaire.htm', '/movie/president.htm', '/movie/sinhal_dweep_ki_sundari.htm', '/movie/300_days_and_after.htm', '/movie/aankh_ka_nashaa.htm', '/movie/aankh_ka_tara_matru_bhakti.htm', '/movie/aawara_shaahzaada.htm', '/movie/abhaagin.htm', '/movie/abul_hasan.htm', '/movie/adhuri_kahani.htm', '/movie/afzal.htm', '/movie/alibaba_40_thieves_1932.htm', '/movie/alif_laila.htm', '/movie/allaadin_the_wonderful_lamp.htm', '/movie/anang_sena.htm']
# ['/movie/anath_ashram.htm', '/movie/aurat_ka_dil.htm', '/movie/ayodhya_ka_raja.htm', '/movie/badi_didi_1939.htm', '/movie/bhaarati_baalak.htm', '/movie/bhaarati_maata.htm', '/movie/bhakta_prahlaad.htm', '/movie/bhartruhari_1932.htm', '/movie/bhola_shikar.htm', '/movie/bhool_bhulaiyan_1933.htm', '/movie/bhutia_mahal.htm', '/movie/brandy_ki_botal.htm', '/movie/bulbulepunjab.htm', '/movie/captain_kirti_kumar.htm', '/movie/chaar_chakram.htm', '/movie/chaar_darvesh.htm', '/movie/chandrahaas.htm', '/movie/chatra_bakavali.htm', '/movie/chintaamani.htm', '/movie/dagabaaz_aashiq.htm']
# ['/movie/dakoo_ki_ladki.htm', '/movie/daku_ka_ladka.htm', '/movie/daku_mansoor_1934.htm', '/movie/daulat_ka_nasha.htm', '/movie/devi_devyaani.htm', '/movie/dhruv_charitra.htm', '/movie/diljaani.htm', '/movie/do_badmaash.htm', '/movie/do_deewane.htm', '/movie/dorangi_duniya.htm', '/movie/gaazi_salauddin.htm', '/movie/ghar_ki_laxmi.htm', '/movie/gharib_ka_laal.htm', '/movie/gul_sanobar.htm', '/movie/gulebakaavali.htm', '/movie/haatimtaai_i.htm', '/movie/haatimtaai_ii.htm', '/movie/haatimtaai_iii.htm', '/movie/haatimtaai_iv.htm', '/movie/hathili_dulhan.htm']
# ['/movie/heer_raanjha.htm', '/movie/idd_ka_chand_1933.htm', '/movie/insaan_ya_shaitaan.htm', '/movie/inteqam_1933.htm', '/movie/jalti_nishani_1932.htm', '/movie/jeevan_naiya.htm', '/movie/jwaala.htm', '/movie/kaala_pahaad.htm', '/movie/karma_fate.htm', '/movie/khoobsoorat_balaa.htm', '/movie/khuda_dost.htm', '/movie/kisan_kanya.htm', '/movie/krishna_sudama_1933.htm', '/movie/krishnaavtar.htm', '/movie/kurukshetra_1933.htm', '/movie/laila_majnu_1931.htm', '/movie/lanka_dahan_1933.htm', '/movie/maalti_maadhav.htm', '/movie/madhuri.htm', '/movie/mahabharat_1933.htm']
# ['/movie/mahageet_1937.htm', '/movie/maya_bazar_1932.htm', '/movie/maya_jaal_1933.htm', '/movie/meerabai_1932.htm', '/movie/mera_ladka.htm', '/movie/meri_aankhen.htm', '/movie/mirza_sahiban.htm', '/movie/miss_1933.htm', '/movie/muflis_aashiq.htm', '/movie/mukti_1937.htm', '/movie/nadi_kinaare.htm', '/movie/nakshe_sulemani.htm', '/movie/nal_damayanti_1933.htm', '/movie/naqli_doctor.htm', '/movie/navchetan.htm', '/movie/nek_abla.htm', '/movie/niti_vijay.htm', '/movie/nooreimaan.htm', '/movie/paak_daaman.htm', '/movie/paakdaaman_raqaasa.htm']
# ['/movie/pandav_kaurav.htm', '/movie/parakh_1937.htm', '/movie/pardesi_preetam.htm', '/movie/patit_paawan.htm', '/movie/pavitra_ganga.htm', '/movie/postman.htm', '/movie/pratima.htm', '/movie/prem_ka_nasha.htm', '/movie/premi_paagal.htm', '/movie/prithviraj_sanyogita.htm', '/movie/raas_vilas.htm', '/movie/radha_krishna_1933.htm', '/movie/radharani.htm', '/movie/radhe_shyam.htm', '/movie/raja_gopichand.htm', '/movie/ramayan_1933.htm', '/movie/rambha_rani.htm', '/movie/rangeela_rajput.htm', '/movie/romantic_prince.htm', '/movie/roop_basant_1933.htm']
# ['/movie/rooplekha.htm', '/movie/roshanara.htm', '/movie/sadhana.htm', '/movie/sant_tulsidas_1934.htm', '/movie/sassi_punnu_1932.htm', '/movie/sati_ansuya.htm', '/movie/sati_madalsa.htm', '/movie/sati_mahananda.htm', '/movie/sati_sone.htm', '/movie/saubhagya_sundari.htm', '/movie/seeta.htm', '/movie/seeta_swayamwar.htm', '/movie/shaanesubhaan.htm', '/movie/shailbala.htm', '/movie/shakuntala_1931.htm', '/movie/shikari_1932.htm', '/movie/shravan_kumar_1932.htm', '/movie/sohni_mahiwal_1933.htm', '/movie/soorya_kumari.htm', '/movie/subah_ka_sitara.htm']
# ['/movie/subhadra_haran_1932.htm', '/movie/sulochana.htm', '/movie/trapped_farebi_jaal.htm', '/movie/turki_sher.htm', '/movie/veer_abhimanyu_1931.htm', '/movie/veer_kunal_1932.htm', '/movie/vikram_charitra.htm', '/movie/vishwa_mohini.htm', '/movie/watan_1938.htm', '/movie/zalim_jawani.htm', '/movie/zarina.htm', '/movie/zehereishq.htm', '/movie/zehree_saanp.htm']
# ['/movie/subhadra_haran_1932.htm', '/movie/sulochana.htm', '/movie/trapped_farebi_jaal.htm', '/movie/turki_sher.htm', '/movie/veer_abhimanyu_1931.htm', '/movie/veer_kunal_1932.htm', '/movie/vikram_charitra.htm', '/movie/vishwa_mohini.htm', '/movie/watan_1938.htm', '/movie/zalim_jawani.htm', '/movie/zarina.htm', '/movie/zehereishq.htm', '/movie/zehree_saanp.htm']
# scraping year 2018
# ['/movie/batti_gul_meter_chalu.htm', '/movie/dhadak.htm', '/movie/gold.htm', '/movie/loveratri.htm', '/movie/nawabzaade.htm', '/movie/satyameva_jayate.htm', '/movie/veere_di_wedding.htm', '/movie/stree_2018.htm', '/movie/102_not_out.htm', '/movie/3_storeys.htm', '/movie/aiyaary.htm', '/movie/angrezi_mein_kehte_hain.htm', '/movie/baa_baaa_black_sheep.htm', '/movie/baaghi_2.htm', '/movie/beyond_the_clouds.htm', '/movie/bhavesh_joshi_superhero.htm', '/movie/billu_ustaad.htm', '/movie/blackmail_2018.htm', '/movie/daas_dev.htm', '/movie/daddys_daughter.htm']
# ['/movie/falooda.htm', '/movie/genius.htm', '/movie/hate_story_iv.htm', '/movie/hichki.htm', '/movie/high_jack.htm', '/movie/hope_aur_hum.htm', '/movie/ishq_tera.htm', '/movie/jaane_kyun_de_yaaron.htm', '/movie/kaala_karikaalan.htm', '/movie/khajoor_pe_atke.htm', '/movie/laila_majnu_2018.htm', '/movie/love_per_square_foot.htm', '/movie/manmarziyaan.htm', '/movie/meri_nimmo.htm', '/movie/my_birthday_song.htm', '/movie/nanu_ki_jaanu.htm', '/movie/nirdosh_2018.htm', '/movie/note_pe_chot_at_811.htm', '/movie/october.htm', '/movie/padmaavat.htm']
# ['/movie/pareshaan_parinda.htm', '/movie/pari.htm', '/movie/parmanu.htm', '/movie/phamous.htm', '/movie/raazi.htm', '/movie/race_3.htm', '/movie/raid.htm', '/movie/raja_abroadiya.htm', '/movie/sanju.htm', '/movie/shaadi_teri_bajayenge_hum_band.htm', '/movie/sonu_ke_titu_ki_sweety.htm', '/movie/soorma.htm', '/movie/tishnagi_2018.htm', '/movie/veerey_ki_wedding.htm', '/movie/vodka_diaries.htm', '/movie/welcome_to_new_york.htm', '/movie/when_obama_loved_osama.htm', '/movie/wo_india_ka_shakespeare.htm', '/movie/yeh_kaisa_tigdam.htm', '/movie/kuchh_bheege_alfaaz.htm']
# ['/movie/the_past.htm', '/movie/2_0.htm', '/movie/5_weddings.htm', '/movie/andhadhun.htm', '/movie/baazaar.htm', '/movie/badhaai_ho.htm', '/movie/bhaagte_raho.htm', '/movie/bhaiaji_superhit.htm', '/movie/bioscopewala.htm', '/movie/bombairiya.htm', '/movie/brij_mohan_amar_rahe.htm', '/movie/chahat_ya_nasha.htm', '/movie/chal_jaa_bapu.htm', '/movie/dassehra.htm', '/movie/dhappa.htm', '/movie/dil_juunglee.htm', '/movie/ekkees_tareekh_shubh_muhurat.htm', '/movie/falsafa.htm', '/movie/fanney_khan.htm', '/movie/game_paisa_ladki.htm']
# ['/movie/halkaa.htm', '/movie/happy_phirr_bhag_jayegi.htm', '/movie/hill_view_villa.htm', '/movie/hotel_milan.htm', '/movie/ishqeria.htm', '/movie/jack_dil.htm', '/movie/jalebi.htm', '/movie/kaashi.htm', '/movie/karim_mohammed.htm', '/movie/karwaan.htm', '/movie/kedarnath.htm', '/movie/kgf_chapter_1.htm', '/movie/khamiyaza.htm', '/movie/kutte_ki_dum.htm', '/movie/lashtam_pashtam.htm', '/movie/little_boy.htm', '/movie/lupt.htm', '/movie/maal_road_dilli.htm', '/movie/manto.htm', '/movie/marudhar_express.htm']
# ['/movie/mausam_ikrar_ke_do_pal_pyar_ke.htm', '/movie/mitron.htm', '/movie/mohalla_assi.htm', '/movie/mulk.htm', '/movie/namaste_england.htm', '/movie/page_16.htm', '/movie/pakhi.htm', '/movie/paltan.htm', '/movie/pataakha.htm', '/movie/petta.htm', '/movie/pihu.htm', '/movie/pk_lele_a_salesman.htm', '/movie/saheb_biwi_aur_gangster_3.htm', '/movie/salt_bridge.htm', '/movie/simmba.htm', '/movie/sui_dhaaga.htm', '/movie/teri_bhabhi_hai_pagle.htm', '/movie/the_dark_side_of_life_mumbai_city.htm', '/movie/the_journey_of_karma.htm', '/movie/the_redrum_a_love_story.htm']
# ['/movie/thugs_of_hindostan.htm', '/movie/tina_lolo.htm', '/movie/tumbbad.htm', '/movie/turning_point.htm', '/movie/vishwaroop_ii.htm', '/movie/yamla_pagla_deewana_phir_se.htm', '/movie/zero.htm']
# ['/movie/thugs_of_hindostan.htm', '/movie/tina_lolo.htm', '/movie/tumbbad.htm', '/movie/turning_point.htm', '/movie/vishwaroop_ii.htm', '/movie/yamla_pagla_deewana_phir_se.htm', '/movie/zero.htm']
# average number of songs for year 1930s is 11.183098591549296
# average number of songs for year 2018 is 4.84251968503937

# %% [markdown]
# # Part III: Web of Science
#
# Scrape a **random sample** of journals on Web of Science from https://mjl.clarivate.com/search-results and answer the following questions:
#
# *What is the category with highest number of journals?*
#
# *What is the category with the smallest number of journals?*
#
# *What are the percentage of journals in each category?*
#
# A random set of pages that you need to scrape are provided to you.
#
# (Hint 1: You might need to find hidden APIs used by this website or use selenium to scrape the website.)
#
# (Hint 2: There might be more than one type of "category" in the data that you scrapped. Try to find the "Journal Citation Report (JCR) category". If you cannot, you are also free to analyze any other type of category.)

# %%
import requests
import json
import time

pages = [1833, 2317, 1506,  699, 1102,  683,  204,  557, 2462,  369, 2233,
       2426,  734, 1415,  372,  881, 2003, 1394, 2136, 1671]

# %%
import json 

def requestOnePage(pageNum, pageSize=10):

    url = 'https://mjl.clarivate.com/api/jprof/public/rank-search'
    payload = {
        'pageSize': pageSize,
        'pageNum': pageNum
        }

    res = requests.post(url, json=payload) # notice that we are using the "POST" method instead of "GET"
    res = json.loads(res.text)
    journalProfiles = [item['journalProfile'] for item in res['journalProfiles']]
    
    return journalProfiles



def parseTitleAndCategory(journal):

  # Write your code below this line
  ######### SOLUTION #########

    df = pd.DataFrame(columns = ['title', 'category'])
    titles = []
    categories = []
    
    for category in journal['categories']: 
            titles.append(journal['publicationTitle'])
            categories.append(category['categoryDescription'])
            
    df['title'] = titles
    df['category'] = categories
    
    return df

# %%
total_df = pd.DataFrame()
for page in pages:
    journals = requestOnePage(page)
    for journal in journals:
        total_df = pd.concat([total_df, parseTitleAndCategory(journal)])
        

total_df.head()
# Out:
#            title                          category
# 0  HEGEL-STUDIEN                        Philosophy
# 1  HEGEL-STUDIEN                        Philosophy
# 2  HEGEL-STUDIEN                        Philosophy
# 0        HE KUPU  Education & Educational Research
# 1        HE KUPU  Education & Educational Research

# %%
total_df.shape
# Out:
# (593, 2)

# %%
counts = total_df['category'].value_counts().reset_index().rename(columns = {'index' : 'category', 'category' : 'count'}).sort_values(by = 'count', ascending = False)
counts.head()
# Out:
#                    category  count
# 0             Neurosciences     22
# 1  Social Sciences, General     18
# 2       Behavioral Sciences     16
# 3    Environmental Sciences     16
# 4                   Zoology     14

# %%
counts.tail()
# Out:
#                                 category  count
# 106  Physical Chemistry/Chemical Physics      1
# 105                     Aquatic Sciences      1
# 104                   Art & Architecture      1
# 103                            Neurology      1
# 123   Environmental Engineering & Energy      1

# %%
total_df['category'].value_counts(normalize = True)
# Out:
# Neurosciences                         0.037099
# Social Sciences, General              0.030354
# Behavioral Sciences                   0.026981
# Environmental Sciences                0.026981
# Zoology                               0.023609
#                                         ...
# Literature                            0.001686
# Medicine, General & Internal          0.001686
# Paleontology                          0.001686
# Agriculture/Agronomy                  0.001686
# Environmental Engineering & Energy    0.001686
# Name: category, Length: 124, dtype: float64
